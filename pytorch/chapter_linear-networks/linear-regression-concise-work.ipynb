# %%
import numpy as np
import torch
from torch.utils import data
from d2l import torch as d2l

# %%
true_w = torch.tensor([2., -3.4])
true_b = torch.tensor(4.2)
num_examples = 1000

features, labels = d2l.synthetic_data(true_w, true_b, num_examples)

# %%
def load_array(data_arrays, batch_size, is_train=True):
    dataset = data.TensorDataset(*data_arrays)
    return data.DataLoader(dataset, batch_size, shuffle=is_train)


batch_size = 10
data_iter = load_array((features, labels), batch_size)

next(iter(data_iter))
# Out:
# [tensor([[ 1.9510, -0.7591],
#          [-1.7607, -0.5033],
#          [-1.3429, -0.3691],
#          [ 0.0261, -0.8050],
#          [ 0.5833,  1.3862],
#          [ 0.1054, -1.8401],
#          [-0.5974,  0.2927],
#          [-0.3062, -0.7229],
#          [ 0.8274,  0.3321],
#          [-0.9414, -0.6336]]),
#  tensor([[10.6537],
#          [ 2.3915],
#          [ 2.7816],
#          [ 6.9881],
#          [ 0.6572],
#          [10.6729],
#          [ 2.0062],
#          [ 6.0278],
#          [ 4.7404],
#          [ 4.4652]])]

# %%
from torch import nn

net = nn.Sequential(nn.Linear(2, 1))

# %%
net[0].weight.data.normal_(0, 0.01)
net[0].bias.data.fill_(0)
# Out:
# tensor([0.])

# %%
loss = nn.HuberLoss()
trainer = torch.optim.SGD(net.parameters(), lr=0.06)

# %%
num_epochs = 3
for epoch in range(num_epochs):
    for X, y in data_iter:
        l = loss(net(X), y)
        trainer.zero_grad()
        l.backward()
        print(f'w grad {net[0].weight.grad}, b grad {net[0].bias.grad}')
        trainer.step()
    l = loss(net(features), labels)
    print(f'epoch {epoch + 1}, loss {l:f}')
# Out:
# w grad tensor([[-0.1874,  0.6536]]), b grad tensor([-0.8000])
# w grad tensor([[-0.5618,  0.3832]]), b grad tensor([-0.7664])
# w grad tensor([[0.1323, 0.6826]]), b grad tensor([-0.7816])
# w grad tensor([[-0.1349, -0.1279]]), b grad tensor([-0.8000])
# w grad tensor([[-0.8784,  0.0983]]), b grad tensor([-0.5586])
# w grad tensor([[0.1221, 0.4159]]), b grad tensor([-0.4829])
# w grad tensor([[-0.3878,  0.8023]]), b grad tensor([-0.4000])
# w grad tensor([[-0.4211,  0.6969]]), b grad tensor([-0.9840])
# w grad tensor([[-0.5804,  0.5607]]), b grad tensor([-0.6000])
# w grad tensor([[-0.4410,  0.1210]]), b grad tensor([-0.7023])
# w grad tensor([[0.3463, 0.2812]]), b grad tensor([-0.7125])
# w grad tensor([[-0.2648,  0.3172]]), b grad tensor([-0.2621])
# w grad tensor([[-0.1386,  0.1788]]), b grad tensor([-0.9525])
# w grad tensor([[-0.5545,  0.7228]]), b grad tensor([-0.6000])
# w grad tensor([[-0.5746,  0.6766]]), b grad tensor([-0.8610])
# w grad tensor([[-0.3995,  0.1589]]), b grad tensor([-0.6850])
# w grad tensor([[-0.0657,  0.7639]]), b grad tensor([-1.0000])
# w grad tensor([[-0.9038,  0.5785]]), b grad tensor([-0.6679])
# w grad tensor([[-0.3224,  0.1248]]), b grad tensor([-0.8000])
# w grad tensor([[-0.5805,  0.1665]]), b grad tensor([-0.3757])
# w grad tensor([[-0.4760,  0.3709]]), b grad tensor([-0.6670])
# w grad tensor([[-0.1403,  0.5480]]), b grad tensor([-0.7423])
# w grad tensor([[0.1097, 0.3214]]), b grad tensor([-0.7011])
# w grad tensor([[-0.3376, -0.0093]]), b grad tensor([-0.9965])
# w grad tensor([[-0.9278,  0.3549]]), b grad tensor([-0.8000])
# w grad tensor([[0.2417, 0.5305]]), b grad tensor([-1.0000])
# w grad tensor([[0.0345, 0.7140]]), b grad tensor([-0.4958])
# w grad tensor([[-0.4840, -0.0276]]), b grad tensor([-0.5900])
# w grad tensor([[-0.4955, -0.1113]]), b grad tensor([-0.7605])
# w grad tensor([[-0.2331,  0.1294]]), b grad tensor([-0.6180])
# w grad tensor([[-0.3689,  0.6625]]), b grad tensor([-0.5440])
# w grad tensor([[0.4563, 0.7782]]), b grad tensor([-1.0000])
# w grad tensor([[-0.1358,  0.4053]]), b grad tensor([-0.7521])
# w grad tensor([[0.0681, 0.1412]]), b grad tensor([-0.9127])
# w grad tensor([[-0.5425,  0.2940]]), b grad tensor([-0.3105])
# w grad tensor([[-0.2937,  0.4071]]), b grad tensor([-0.7260])
# w grad tensor([[-0.4301, -0.0055]]), b grad tensor([-0.5880])
# w grad tensor([[-0.5492,  0.9315]]), b grad tensor([-0.4340])
# w grad tensor([[-0.0468,  0.2397]]), b grad tensor([-0.4550])
# w grad tensor([[-0.1878,  0.4511]]), b grad tensor([-0.8614])
# w grad tensor([[-0.1128,  0.5793]]), b grad tensor([-0.5102])
# w grad tensor([[-1.3292,  0.3545]]), b grad tensor([-0.4348])
# w grad tensor([[-0.2761,  0.7882]]), b grad tensor([-0.4099])
# w grad tensor([[-0.7446,  0.0175]]), b grad tensor([-0.8029])
# w grad tensor([[-0.6287,  0.6261]]), b grad tensor([-0.8090])
# w grad tensor([[-0.4435,  0.5622]]), b grad tensor([-0.4680])
# w grad tensor([[0.1904, 0.3977]]), b grad tensor([-0.8547])
# w grad tensor([[-1.2003,  0.2638]]), b grad tensor([-0.5308])
# w grad tensor([[-0.3094, -0.0672]]), b grad tensor([-0.8302])
# w grad tensor([[-0.3271,  0.6310]]), b grad tensor([-0.5457])
# w grad tensor([[-0.1543,  0.4612]]), b grad tensor([-0.2653])
# w grad tensor([[-0.6388,  0.3253]]), b grad tensor([-0.6911])
# w grad tensor([[-0.2772,  0.3088]]), b grad tensor([-0.7135])
# w grad tensor([[-0.6059,  0.3786]]), b grad tensor([-0.7773])
# w grad tensor([[-0.7866,  0.5295]]), b grad tensor([-0.0610])
# w grad tensor([[-0.3604,  0.2657]]), b grad tensor([-0.5614])
# w grad tensor([[-0.5805,  0.7463]]), b grad tensor([-0.5739])
# w grad tensor([[-0.0673,  0.6462]]), b grad tensor([-0.8000])
# w grad tensor([[0.3451, 0.2398]]), b grad tensor([-0.7153])
# w grad tensor([[-0.5825,  0.3753]]), b grad tensor([-0.7057])
# w grad tensor([[0.1242, 0.3980]]), b grad tensor([-0.8945])
# w grad tensor([[-0.5589,  0.2166]]), b grad tensor([-0.7463])
# w grad tensor([[0.0761, 0.6973]]), b grad tensor([-0.7700])
# w grad tensor([[-0.2051,  0.3049]]), b grad tensor([-0.5557])
# w grad tensor([[0.1254, 0.1418]]), b grad tensor([-0.4147])
# w grad tensor([[-0.2377,  0.3370]]), b grad tensor([-0.4372])
# w grad tensor([[-0.4944,  0.6438]]), b grad tensor([-0.8371])
# w grad tensor([[-0.4624,  0.5815]]), b grad tensor([-0.3004])
# w grad tensor([[-0.6875,  0.1616]]), b grad tensor([-0.3053])
# w grad tensor([[0.0192, 0.1277]]), b grad tensor([-0.8090])
# w grad tensor([[-0.0924,  0.5437]]), b grad tensor([-0.3587])
# w grad tensor([[-0.9176,  0.3478]]), b grad tensor([-0.6551])
# w grad tensor([[0.1474, 0.2354]]), b grad tensor([-0.4983])
# w grad tensor([[-0.4964,  0.3215]]), b grad tensor([-0.4109])
# w grad tensor([[0.0953, 0.6850]]), b grad tensor([-0.6845])
# w grad tensor([[-0.0359,  0.5755]]), b grad tensor([-0.2603])
# w grad tensor([[-0.2354,  0.7518]]), b grad tensor([-0.5804])
# w grad tensor([[-0.4361,  0.3374]]), b grad tensor([-0.6493])
# w grad tensor([[-0.2878,  0.5872]]), b grad tensor([-0.7372])
# w grad tensor([[-0.2416,  0.3167]]), b grad tensor([-0.2998])
# w grad tensor([[-0.1061,  0.4485]]), b grad tensor([-0.6508])
# w grad tensor([[0.0482, 0.4856]]), b grad tensor([-0.6181])
# w grad tensor([[-0.4357,  0.2210]]), b grad tensor([-0.7638])
# w grad tensor([[-0.6228,  0.5686]]), b grad tensor([-0.7136])
# w grad tensor([[-0.3600,  0.8025]]), b grad tensor([-0.1211])
# w grad tensor([[-0.6189,  0.4008]]), b grad tensor([-0.5811])
# w grad tensor([[-0.1652,  0.6116]]), b grad tensor([-0.8842])
# w grad tensor([[-0.2646,  0.7222]]), b grad tensor([-0.5105])
# w grad tensor([[0.0425, 0.9343]]), b grad tensor([-0.4579])
# w grad tensor([[-0.2058,  0.6243]]), b grad tensor([-0.3212])
# w grad tensor([[-0.1498,  0.7600]]), b grad tensor([-0.1882])
# w grad tensor([[-0.0109,  1.0008]]), b grad tensor([-0.5299])
# w grad tensor([[-0.3575,  0.2989]]), b grad tensor([-0.4471])
# w grad tensor([[-0.3400,  0.3607]]), b grad tensor([-0.1480])
# w grad tensor([[0.0560, 0.7590]]), b grad tensor([-0.6426])
# w grad tensor([[-0.1502,  0.2617]]), b grad tensor([-0.2808])
# w grad tensor([[-0.2231,  0.4243]]), b grad tensor([-0.6204])
# w grad tensor([[-0.0354,  0.4781]]), b grad tensor([-0.2227])
# w grad tensor([[-0.2233,  0.6789]]), b grad tensor([-0.1375])
# w grad tensor([[0.1976, 0.6754]]), b grad tensor([-0.4404])
# epoch 1, loss 0.427579
# w grad tensor([[-0.1673,  0.3508]]), b grad tensor([-0.3233])
# w grad tensor([[-0.1381,  0.1798]]), b grad tensor([-0.5340])
# w grad tensor([[-0.2188,  0.5515]]), b grad tensor([-0.4516])
# w grad tensor([[-0.3416,  0.5342]]), b grad tensor([-0.3536])
# w grad tensor([[-0.3116,  0.6701]]), b grad tensor([-0.7223])
# w grad tensor([[0.1173, 0.1200]]), b grad tensor([-0.0933])
# w grad tensor([[-0.0015,  0.3497]]), b grad tensor([-0.5242])
# w grad tensor([[-0.3871,  0.3593]]), b grad tensor([-0.1202])
# w grad tensor([[-0.1187,  0.3924]]), b grad tensor([-0.4711])
# w grad tensor([[-0.0819,  0.5076]]), b grad tensor([-0.3214])
# w grad tensor([[-0.2921,  0.1395]]), b grad tensor([-0.0123])
# w grad tensor([[-0.1946,  0.2331]]), b grad tensor([-0.2968])
# w grad tensor([[-0.2356,  0.2786]]), b grad tensor([-0.3537])
# w grad tensor([[0.0503, 0.6098]]), b grad tensor([-0.1378])
# w grad tensor([[-0.0314,  0.3776]]), b grad tensor([-0.3204])
# w grad tensor([[-0.0302,  0.4269]]), b grad tensor([-0.4461])
# w grad tensor([[-0.1553,  0.4974]]), b grad tensor([-0.2943])
# w grad tensor([[-0.6244,  0.5082]]), b grad tensor([-0.2883])
# w grad tensor([[-0.0472,  0.2584]]), b grad tensor([-0.3355])
# w grad tensor([[-0.2945,  0.0968]]), b grad tensor([-0.2190])
# w grad tensor([[-0.0920,  0.1771]]), b grad tensor([-0.0031])
# w grad tensor([[-0.0748,  0.3122]]), b grad tensor([-0.2683])
# w grad tensor([[-0.0363,  0.3714]]), b grad tensor([-0.0471])
# w grad tensor([[-0.1318,  0.5381]]), b grad tensor([-0.3239])
# w grad tensor([[-0.0240,  0.0950]]), b grad tensor([-0.1807])
# w grad tensor([[0.0207, 0.2884]]), b grad tensor([-0.0935])
# w grad tensor([[-0.1099,  0.1606]]), b grad tensor([-0.2123])
# w grad tensor([[0.0065, 0.1312]]), b grad tensor([-0.0297])
# w grad tensor([[-0.0438,  0.0538]]), b grad tensor([-0.0731])
# w grad tensor([[-0.0439,  0.2530]]), b grad tensor([-0.1987])
# w grad tensor([[-0.1125,  0.2048]]), b grad tensor([-0.0964])
# w grad tensor([[0.1137, 0.1671]]), b grad tensor([0.0101])
# w grad tensor([[0.0845, 0.0849]]), b grad tensor([-0.0386])
# w grad tensor([[0.1160, 0.2554]]), b grad tensor([-0.1037])
# w grad tensor([[0.0391, 0.1227]]), b grad tensor([-0.1314])
# w grad tensor([[0.0162, 0.2211]]), b grad tensor([-0.1393])
# w grad tensor([[-0.0441,  0.0795]]), b grad tensor([-0.0692])
# w grad tensor([[-0.0513,  0.1891]]), b grad tensor([-0.0099])
# w grad tensor([[-0.0616,  0.0869]]), b grad tensor([-0.0527])
# w grad tensor([[-0.0139,  0.0157]]), b grad tensor([-0.0449])
# w grad tensor([[-0.0016,  0.1243]]), b grad tensor([-0.0968])
# w grad tensor([[0.0082, 0.0435]]), b grad tensor([-0.0249])
# w grad tensor([[-0.0011,  0.0556]]), b grad tensor([-0.0358])
# w grad tensor([[-0.0936,  0.2384]]), b grad tensor([-0.0857])
# w grad tensor([[0.0093, 0.0689]]), b grad tensor([-0.0427])
# w grad tensor([[-0.0098,  0.1337]]), b grad tensor([-0.0503])
# w grad tensor([[-0.0515,  0.0660]]), b grad tensor([-0.0623])
# w grad tensor([[0.0021, 0.0898]]), b grad tensor([-0.0790])
# w grad tensor([[-0.0139,  0.0339]]), b grad tensor([-0.0356])
# w grad tensor([[0.0076, 0.0446]]), b grad tensor([-0.0167])
# w grad tensor([[-0.0373,  0.0780]]), b grad tensor([-0.0370])
# w grad tensor([[-0.0097,  0.0489]]), b grad tensor([0.0010])
# w grad tensor([[-0.0031,  0.0540]]), b grad tensor([-0.0325])
# w grad tensor([[0.0014, 0.0461]]), b grad tensor([-0.0165])
# w grad tensor([[-0.0145,  0.0305]]), b grad tensor([0.0027])
# w grad tensor([[0.0260, 0.0244]]), b grad tensor([-0.0273])
# w grad tensor([[0.0185, 0.0311]]), b grad tensor([-0.0113])
# w grad tensor([[-0.0027,  0.0100]]), b grad tensor([-0.0188])
# w grad tensor([[-0.0017,  0.0457]]), b grad tensor([-0.0218])
# w grad tensor([[0.0019, 0.0158]]), b grad tensor([-0.0058])
# w grad tensor([[-0.0123,  0.0326]]), b grad tensor([-0.0262])
# w grad tensor([[0.0034, 0.0060]]), b grad tensor([-0.0110])
# w grad tensor([[0.0008, 0.0097]]), b grad tensor([-0.0196])
# w grad tensor([[0.0060, 0.0060]]), b grad tensor([-0.0157])
# w grad tensor([[-0.0154,  0.0121]]), b grad tensor([-0.0093])
# w grad tensor([[-0.0022,  0.0198]]), b grad tensor([0.0041])
# w grad tensor([[0.0090, 0.0215]]), b grad tensor([-0.0084])
# w grad tensor([[-0.0113,  0.0068]]), b grad tensor([-0.0061])
# w grad tensor([[-0.0060,  0.0157]]), b grad tensor([-0.0148])
# w grad tensor([[-0.0063,  0.0041]]), b grad tensor([-0.0116])
# w grad tensor([[-0.0047,  0.0255]]), b grad tensor([-0.0193])
# w grad tensor([[-0.0058,  0.0056]]), b grad tensor([-0.0091])
# w grad tensor([[-0.0025,  0.0127]]), b grad tensor([-0.0085])
# w grad tensor([[0.0043, 0.0253]]), b grad tensor([-0.0030])
# w grad tensor([[-0.0039,  0.0217]]), b grad tensor([-0.0161])
# w grad tensor([[0.0053, 0.0075]]), b grad tensor([-0.0042])
# w grad tensor([[-0.0106,  0.0162]]), b grad tensor([-0.0013])
# w grad tensor([[-0.0026,  0.0017]]), b grad tensor([-0.0117])
# w grad tensor([[0.0011, 0.0026]]), b grad tensor([-0.0045])
# w grad tensor([[-0.0062,  0.0047]]), b grad tensor([-0.0062])
# w grad tensor([[-0.0006,  0.0033]]), b grad tensor([-0.0031])
# w grad tensor([[0.0021, 0.0143]]), b grad tensor([0.0088])
# w grad tensor([[-0.0014,  0.0088]]), b grad tensor([-0.0081])
# w grad tensor([[0.0012, 0.0038]]), b grad tensor([-0.0067])
# w grad tensor([[-0.0023,  0.0024]]), b grad tensor([-0.0014])
# w grad tensor([[-8.5861e-05,  6.9720e-03]]), b grad tensor([-0.0064])
# w grad tensor([[0.0059, 0.0046]]), b grad tensor([-0.0103])
# w grad tensor([[-0.0023,  0.0184]]), b grad tensor([-0.0051])
# w grad tensor([[0.0003, 0.0122]]), b grad tensor([-0.0039])
# w grad tensor([[-0.0060,  0.0010]]), b grad tensor([-0.0071])
# w grad tensor([[-0.0007,  0.0006]]), b grad tensor([0.0004])
# w grad tensor([[-0.0014,  0.0078]]), b grad tensor([0.0010])
# w grad tensor([[-0.0057,  0.0052]]), b grad tensor([-0.0013])
# w grad tensor([[0.0004, 0.0018]]), b grad tensor([0.0035])
# w grad tensor([[-0.0007,  0.0038]]), b grad tensor([0.0011])
# w grad tensor([[0.0053, 0.0077]]), b grad tensor([-0.0056])
# w grad tensor([[2.1344e-05, 9.8506e-04]]), b grad tensor([0.0017])
# w grad tensor([[0.0028, 0.0016]]), b grad tensor([0.0040])
# w grad tensor([[-0.0007, -0.0001]]), b grad tensor([-0.0012])
# w grad tensor([[-0.0008,  0.0065]]), b grad tensor([-0.0115])
# epoch 2, loss 0.000059
# w grad tensor([[-0.0022, -0.0010]]), b grad tensor([-0.0014])
# w grad tensor([[0.0002, 0.0038]]), b grad tensor([-0.0035])
# w grad tensor([[0.0004, 0.0004]]), b grad tensor([-0.0035])
# w grad tensor([[-0.0012, -0.0068]]), b grad tensor([0.0002])
# w grad tensor([[0.0006, 0.0020]]), b grad tensor([-0.0012])
# w grad tensor([[0.0019, 0.0041]]), b grad tensor([0.0014])
# w grad tensor([[ 0.0002, -0.0002]]), b grad tensor([0.0024])
# w grad tensor([[-0.0028,  0.0004]]), b grad tensor([-0.0002])
# w grad tensor([[-0.0020,  0.0045]]), b grad tensor([-0.0046])
# w grad tensor([[0.0076, 0.0046]]), b grad tensor([-0.0024])
# w grad tensor([[0.0097, 0.0025]]), b grad tensor([-0.0015])
# w grad tensor([[-0.0004,  0.0035]]), b grad tensor([0.0052])
# w grad tensor([[ 0.0019, -0.0014]]), b grad tensor([-0.0045])
# w grad tensor([[-0.0009, -0.0001]]), b grad tensor([0.0034])
# w grad tensor([[0.0014, 0.0012]]), b grad tensor([0.0010])
# w grad tensor([[0.0004, 0.0029]]), b grad tensor([-0.0026])
# w grad tensor([[-0.0016, -0.0026]]), b grad tensor([-0.0021])
# w grad tensor([[4.4566e-03, 4.7717e-05]]), b grad tensor([-0.0019])
# w grad tensor([[-0.0003, -0.0024]]), b grad tensor([0.0020])
# w grad tensor([[-0.0013,  0.0029]]), b grad tensor([-0.0022])
# w grad tensor([[ 0.0042, -0.0048]]), b grad tensor([-0.0017])
# w grad tensor([[ 0.0004, -0.0024]]), b grad tensor([-0.0055])
# w grad tensor([[-0.0015,  0.0113]]), b grad tensor([-0.0033])
# w grad tensor([[-0.0039,  0.0049]]), b grad tensor([0.0008])
# w grad tensor([[-0.0040, -0.0032]]), b grad tensor([-0.0018])
# w grad tensor([[-0.0013,  0.0020]]), b grad tensor([-0.0042])
# w grad tensor([[0.0016, 0.0023]]), b grad tensor([0.0024])
# w grad tensor([[-0.0003,  0.0054]]), b grad tensor([0.0010])
# w grad tensor([[-0.0048,  0.0016]]), b grad tensor([-0.0058])
# w grad tensor([[ 0.0018, -0.0062]]), b grad tensor([-0.0005])
# w grad tensor([[-3.9608e-05, -3.8090e-03]]), b grad tensor([-0.0020])
# w grad tensor([[0.0009, 0.0029]]), b grad tensor([-0.0014])
# w grad tensor([[0.0050, 0.0002]]), b grad tensor([-0.0012])
# w grad tensor([[-0.0004,  0.0043]]), b grad tensor([0.0035])
# w grad tensor([[ 0.0056, -0.0055]]), b grad tensor([0.0020])
# w grad tensor([[ 0.0005, -0.0016]]), b grad tensor([0.0037])
# w grad tensor([[ 0.0009, -0.0050]]), b grad tensor([-0.0018])
# w grad tensor([[0.0073, 0.0028]]), b grad tensor([0.0037])
# w grad tensor([[-0.0020, -0.0008]]), b grad tensor([0.0009])
# w grad tensor([[-0.0038,  0.0046]]), b grad tensor([0.0052])
# w grad tensor([[ 0.0047, -0.0032]]), b grad tensor([-0.0008])
# w grad tensor([[-0.0033,  0.0002]]), b grad tensor([0.0010])
# w grad tensor([[-1.5631e-05, -2.6640e-04]]), b grad tensor([0.0042])
# w grad tensor([[0.0074, 0.0011]]), b grad tensor([0.0018])
# w grad tensor([[-0.0023,  0.0063]]), b grad tensor([0.0008])
# w grad tensor([[ 0.0006, -0.0004]]), b grad tensor([0.0032])
# w grad tensor([[-0.0021,  0.0006]]), b grad tensor([0.0013])
# w grad tensor([[ 0.0053, -0.0034]]), b grad tensor([-0.0059])
# w grad tensor([[0.0053, 0.0002]]), b grad tensor([-0.0034])
# w grad tensor([[ 0.0006, -0.0052]]), b grad tensor([7.4915e-06])
# w grad tensor([[0.0014, 0.0006]]), b grad tensor([-0.0008])
# w grad tensor([[ 0.0011, -0.0009]]), b grad tensor([0.0062])
# w grad tensor([[-0.0033, -0.0015]]), b grad tensor([0.0015])
# w grad tensor([[-0.0010,  0.0056]]), b grad tensor([-0.0040])
# w grad tensor([[-0.0020,  0.0012]]), b grad tensor([-0.0012])
# w grad tensor([[ 0.0044, -0.0047]]), b grad tensor([-0.0066])
# w grad tensor([[-0.0018, -0.0043]]), b grad tensor([-0.0003])
# w grad tensor([[-0.0023,  0.0013]]), b grad tensor([-2.4108e-06])
# w grad tensor([[-5.7476e-05, -1.7322e-03]]), b grad tensor([0.0013])
# w grad tensor([[0.0010, 0.0025]]), b grad tensor([0.0023])
# w grad tensor([[ 0.0025, -0.0025]]), b grad tensor([0.0010])
# w grad tensor([[-0.0046, -0.0029]]), b grad tensor([-0.0075])
# w grad tensor([[0.0008, 0.0030]]), b grad tensor([0.0007])
# w grad tensor([[1.8326e-03, 8.2879e-05]]), b grad tensor([0.0010])
# w grad tensor([[-1.0437e-05, -1.3514e-03]]), b grad tensor([-0.0019])
# w grad tensor([[-0.0018, -0.0042]]), b grad tensor([-0.0009])
# w grad tensor([[-0.0040,  0.0022]]), b grad tensor([-0.0056])
# w grad tensor([[-0.0002, -0.0005]]), b grad tensor([0.0057])
# w grad tensor([[ 0.0011, -0.0022]]), b grad tensor([0.0060])
# w grad tensor([[2.7328e-03, 4.7924e-05]]), b grad tensor([0.0030])
# w grad tensor([[-0.0049, -0.0020]]), b grad tensor([0.0001])
# w grad tensor([[ 0.0029, -0.0031]]), b grad tensor([-0.0019])
# w grad tensor([[-0.0046,  0.0074]]), b grad tensor([-0.0021])
# w grad tensor([[0.0007, 0.0055]]), b grad tensor([-0.0062])
# w grad tensor([[ 0.0008, -0.0035]]), b grad tensor([-0.0005])
# w grad tensor([[ 0.0004, -0.0049]]), b grad tensor([-0.0004])
# w grad tensor([[-0.0029, -0.0020]]), b grad tensor([-0.0028])
# w grad tensor([[-0.0012,  0.0030]]), b grad tensor([-0.0003])
# w grad tensor([[ 0.0027, -0.0014]]), b grad tensor([0.0045])
# w grad tensor([[0.0003, 0.0048]]), b grad tensor([-0.0040])
# w grad tensor([[-0.0050, -0.0048]]), b grad tensor([-0.0032])
# w grad tensor([[0.0073, 0.0013]]), b grad tensor([-0.0033])
# w grad tensor([[-0.0013,  0.0034]]), b grad tensor([0.0024])
# w grad tensor([[-0.0006,  0.0007]]), b grad tensor([-0.0001])
# w grad tensor([[-0.0043,  0.0056]]), b grad tensor([0.0019])
# w grad tensor([[-0.0013,  0.0034]]), b grad tensor([-0.0024])
# w grad tensor([[ 0.0020, -0.0003]]), b grad tensor([0.0002])
# w grad tensor([[-0.0004,  0.0050]]), b grad tensor([-0.0008])
# w grad tensor([[-0.0079,  0.0056]]), b grad tensor([0.0024])
# w grad tensor([[-0.0067,  0.0049]]), b grad tensor([0.0009])
# w grad tensor([[-0.0051, -0.0003]]), b grad tensor([0.0007])
# w grad tensor([[ 0.0024, -0.0019]]), b grad tensor([-0.0008])
# w grad tensor([[ 0.0053, -0.0058]]), b grad tensor([0.0002])
# w grad tensor([[-0.0039,  0.0009]]), b grad tensor([-0.0030])
# w grad tensor([[-0.0024, -0.0039]]), b grad tensor([-0.0043])
# w grad tensor([[-0.0023,  0.0045]]), b grad tensor([0.0028])
# w grad tensor([[0.0014, 0.0004]]), b grad tensor([-0.0011])
# w grad tensor([[ 2.7833e-03, -5.8959e-05]]), b grad tensor([-0.0003])
# w grad tensor([[-0.0005, -0.0025]]), b grad tensor([-0.0025])
# w grad tensor([[-5.8219e-05, -1.1515e-03]]), b grad tensor([0.0013])
# epoch 3, loss 0.000056
